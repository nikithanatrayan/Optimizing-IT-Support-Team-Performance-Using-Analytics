# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\user\Documents\raw data.xlsx")

# %%
print(df.head())
print(df.shape)
print(df.info())
# Out:
#                                              subject  \
# 0                    Wesentlicher Sicherheitsvorfall
# 1                                 Account Disruption
# 2  Query About Smart Home System Integration Feat...
# 3                  Inquiry Regarding Invoice Details
# 4  Question About Marketing Agency Software Compa...
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team,\n\nich mÃ¶chte ein...
# 1  Dear Customer Support Team,\n\nI am writing to...
# 2  Dear Customer Support Team,\n\nI hope this mes...
# 3  Dear Customer Support Team,\n\nI hope this mes...
# 4  Dear Support Team,\n\nI hope this message reac...
#
#                                               answer      type  \
# 0  Vielen Dank fÃ¼r die Meldung des kritischen Si...  Incident
# 1  Thank you for reaching out, <name>. We are awa...  Incident
# 2  Thank you for your inquiry. Our products suppo...   Request
# 3  We appreciate you reaching out with your billi...   Request
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.drop("body", axis=1, errors="ignore")
df = df.drop("tag_5", axis=1, errors="ignore")
df = df.drop("tag_6", axis=1, errors="ignore")
df = df.drop("tag_7", axis=1, errors="ignore")
df = df.drop("tag_8", axis=1, errors="ignore")
df = df.drop("answer", axis=1, errors="ignore")

# %%
print(df.isnull().sum())
# Out:
# subject     0
# type        0
# queue       0
# priority    0
# language    0
# version     0
# tag_1       0
# tag_2       0
# tag_3       0
# tag_4       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['subject', 'type', 'queue', 'priority', 'language', 'version', 'tag_1',
#        'tag_2', 'tag_3', 'tag_4'],
#       dtype='object')

# %%
df.tail()
# Out:
#                                                subject      type  \
# 542  Request for Architectural Specifications of th...   Request
# 543     Discrepancies in Billing Across Multiple Items  Incident
# 544                                Dienstunterbrechung   Problem
# 545  Anfrage zur UnterstÃ¼tzung und KlÃ¤rung des Su...  Incident
# 546  Request for Clarification on Billing and Payme...   Request
#
#                     queue priority language  version    tag_1         tag_2  \
# 542      Customer Service      low       de       51  Product       Feature
# 543  Billing and Payments   medium       de       51  Billing       Account
# 544      Customer Service     high       de       51   Outage    Disruption
# 545       General Inquiry   medium       de       51  Support  Tech Support
# 546  Billing and Payments   medium       en       51  Billing       Payment
#
#            tag_3          tag_4
# 542           IT   Tech Support
# 543     Software    Discrepancy
# ...

# %%
df.sample(5)
# Out:
#                                                subject      type  \
# 399  Dringender Sicherheitszwischenfall, Schnittste...  Incident
# 346      Connectivity Problems Across Multiple Devices  Incident
# 285                                           Anliegen   Problem
# 23                 Multiple Device Connection Problems  Incident
# 91    Inquiry for In-Depth Product Integration Details   Request
#
#                  queue priority language  version     tag_1       tag_2  \
# 399  Technical Support     high       de       51  Security     Network
# 346  Technical Support     high       en       51   Network  Disruption
# 285    Product Support   medium       de       51   Account     Support
# 23          IT Support   medium       en       51   Network  Disruption
# 91          IT Support     high       en       51   Product     Feature
#
#              tag_3         tag_4
# 399         Outage    Disruption
# 346             IT  Tech Support
# 285       Workflow         Delay
# ...

# %%
df.head()
df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 517 entries, 0 to 546
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   517 non-null    object
#  1   type      517 non-null    object
#  2   queue     517 non-null    object
#  3   priority  517 non-null    object
#  4   language  517 non-null    object
#  5   version   517 non-null    int64
#  6   tag_1     517 non-null    object
#  7   tag_2     517 non-null    object
#  8   tag_3     517 non-null    object
#  9   tag_4     517 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 44.4+ KB
# subject     0
# type        0
# queue       0
# priority    0
# language    0
# version     0
# tag_1       0
# tag_2       0
# tag_3       0
# tag_4       0
# dtype: int64
